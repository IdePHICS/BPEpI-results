# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib
from matplotlib import cm
import matplotlib.pyplot as plt
from matplotlib.backends.backend_pdf import PdfPages
import pickle
import lzma
import matplotlib.ticker as ticker
import scipy

load_dir = '../Data/'
save_dir = "../Plots/"
save_fig = 0 #Change to 1 when you want to save figures

# %%
N=10000
graph="rrg"
d=3

# %%
r_s = r"$\rho$"
l_s = r"$\lambda$"
del_s = r"$\delta$"
N_s = r"$N$"
st_s = "snap_time"

# %%
file_name = f"Fig9.xz"

with lzma.open(load_dir + file_name, "rb") as f:
    dat = pickle.load(f)

# %%
st = 10

# %%
df = dat#[(dat["snap_time"]==st) & (dat["S"]==0.005)]

# %%
sns.set_theme(style="whitegrid", font_scale=1.5)
fig,axs = plt.subplots(2,3, figsize=(24,12), sharex=True, sharey=True)
#plt.suptitle(f"Bw-Inf, {l_s} = 0.5, {del_s} = 0.005, {N_s} = {N}, {d}-{graph}")
#init_s = "rnd"
sns.lineplot(data=df[df["snap_time"]==12], x="iteration", hue = "seed", style="init", y=r"$R_{MSE}$",legend=True, ax=axs[0][0])
sns.lineplot(data=df[(df["snap_time"]==13)], x="iteration", hue = "seed", style="init", y=r"$R_{MSE}$",legend=False, ax=axs[0][1])
sns.lineplot(data=df[df["snap_time"]==14], x="iteration", hue = "seed", style="init", y=r"$R_{MSE}$",legend=False, ax=axs[0][2])
sns.lineplot(data=df[df["snap_time"]==15], x="iteration", hue = "seed", style="init", y=r"$R_{MSE}$",legend=False, ax=axs[1][0])
sns.lineplot(data=df[df["snap_time"]==16], x="iteration", hue = "seed", style="init", y=r"$R_{MSE}$",legend=False, ax=axs[1][1])
sns.lineplot(data=df[df["snap_time"]==17], x="iteration", hue = "seed", style="init", y=r"$R_{MSE}$",legend=False, ax=axs[1][2])
axs[0][0].set_xscale("symlog")
axs[0][0].set_xlim([0,1000])
axs[0][0].set_title(r"$T_{\rm obs} = 12$")
axs[0][0].set_ylabel(r"$R_{\rm MSE}$")
axs[0][1].set_title(r"$T_{\rm obs} = 13$")
axs[0][2].set_title(r"$T_{\rm obs} = 14$")
axs[1][0].set_title(r"$T_{\rm obs} = 15$")
axs[1][0].set_ylabel(r"$R_{\rm MSE}$")
axs[1][1].set_title(r"$T_{\rm obs} = 16$")
axs[1][2].set_title(r"$T_{\rm obs} = 17$")
plt.tight_layout()
fig.savefig(save_dir + f"Figure9.pdf")

# %% [markdown]
# # Part 2

# %%
file_name = f"Fig12.xz"

with lzma.open(load_dir + file_name, "rb") as f:
    dat = pickle.load(f)

# %%
df = dat[dat["init"]=="rnd"]#[(dat["snap_time"]==st) & (dat["S"]==0.005)]
df
# Out:
#      init graph_type    $N$  $d$  $\lambda$ s_type      S o_type    M  \
# 0     rnd        rrg  10000    3        0.5  delta  0.005    rho  1.0
# 1     rnd        rrg  10000    3        0.5  delta  0.005    rho  1.0
# 2     rnd        rrg  10000    3        0.5  delta  0.005    rho  1.0
# 3     rnd        rrg  10000    3        0.5  delta  0.005    rho  1.0
# 4     rnd        rrg  10000    3        0.5  delta  0.005    rho  1.0
# ...   ...        ...    ...  ...        ...    ...    ...    ...  ...
# 6139  rnd        rrg  10000    3        0.5  delta  0.005    rho  1.0
# 6140  rnd        rrg  10000    3        0.5  delta  0.005    rho  1.0
# 6141  rnd        rrg  10000    3        0.5  delta  0.005    rho  1.0
# 6142  rnd        rrg  10000    3        0.5  delta  0.005    rho  1.0
# 6143  rnd        rrg  10000    3        0.5  delta  0.005    rho  1.0
#
#       iter_space  ...        SE        MSE  $SE_{RND}$ $MSE_{RND}$  \
# 0              1  ...  9.778878   9.310963    9.778787    9.310963
# 1              1  ...  9.743773   9.283941    9.778036    9.317209
# 2              1  ...  9.714496   9.261901    9.777117    9.323415
# 3              1  ...  9.668809   9.244014    9.774256    9.326600
# 4              1  ...  9.644582   9.233208    9.773032    9.326449
# ...          ...  ...       ...        ...         ...         ...
# 6139           1  ...  9.871278   7.767842   11.067507    8.419402
# 6140           1  ...  9.545860   8.306053   10.781380    9.043093
# 6141           1  ...  9.089712   9.111977   10.373021   10.001414
# 6142           1  ...  8.574126  10.278427    9.894379   11.446776
# 6143           1  ...  8.271068  11.831396    9.553757   13.519075
#
#       $\delta SE$  $R_{SE}$     $R_{MSE}$  $\delta R_{SE}$  \
# 0        0.467915 -0.000009  9.699477e-10        -0.000009
# 1        0.459832  0.003504  3.570561e-03        -0.000066
# 2        0.452595  0.006405  6.597739e-03        -0.000193
# 3        0.424795  0.010788  8.854878e-03         0.001933
# 4        0.411374  0.013143  9.997481e-03         0.003146
# ...           ...       ...           ...              ...
# 6139     2.103436  0.108085  7.738799e-02         0.030697
# 6140     1.239807  0.114598  8.150310e-02         0.033094
# 6141    -0.022264  0.123716  8.893113e-02         0.034785
# 6142    -1.704302  0.133435  1.020680e-01         0.031367
# 6143    -3.560329  0.134260  1.248369e-01         0.009423
#
#                                              ConvChecks  $SE_{mess}$
# 0     [[10, 0.0039010942, 1.5112587e-05], [20, 0.000...     0.000406
# 1     [[10, 0.0039010942, 1.5112587e-05], [20, 0.000...     0.000150
# 2     [[10, 0.0039010942, 1.5112587e-05], [20, 0.000...     0.000087
# 3     [[10, 0.0039010942, 1.5112587e-05], [20, 0.000...     0.000061
# 4     [[10, 0.0039010942, 1.5112587e-05], [20, 0.000...     0.000050
# ...                                                 ...          ...
# 6139  [[10, 0.0058137756, 6.118741e-05], [20, 0.0020...     0.000002
# 6140  [[10, 0.0058137756, 6.118741e-05], [20, 0.0020...     0.000004
# 6141  [[10, 0.0058137756, 6.118741e-05], [20, 0.0020...     0.000006
# 6142  [[10, 0.0058137756, 6.118741e-05], [20, 0.0020...     0.000009
# 6143  [[10, 0.0058137756, 6.118741e-05], [20, 0.0020...     0.000011
#
# [3105 rows x 58 columns]

# %%
lw=2.5
sns.set_theme(style="whitegrid", font_scale=1.5)
fig,axs = plt.subplots(2,3, figsize=(24,12), sharex=True, sharey=True)
#plt.suptitle(f"Bw-Inf, {l_s} = 0.5, {del_s} = 0.005, {N_s} = {N}, {d}-{graph}")
#init_s = "rnd"
sns.lineplot(data=df[df["snap_time"]==12], x="iteration", hue = "seed", y=r"$SE_{mess}$",legend=True, ax=axs[0][0],linewidth=lw)
sns.lineplot(data=df[(df["snap_time"]==13)], x="iteration", hue = "seed", y=r"$SE_{mess}$",legend=False, ax=axs[0][1],linewidth=lw)
sns.lineplot(data=df[df["snap_time"]==14], x="iteration", hue = "seed", y=r"$SE_{mess}$",legend=False, ax=axs[0][2],linewidth=lw)
sns.lineplot(data=df[df["snap_time"]==15], x="iteration", hue = "seed", y=r"$SE_{mess}$",legend=False, ax=axs[1][0],linewidth=lw)
sns.lineplot(data=df[df["snap_time"]==16], x="iteration", hue = "seed", y=r"$SE_{mess}$",legend=False, ax=axs[1][1],linewidth=lw)
sns.lineplot(data=df[df["snap_time"]==17], x="iteration", hue = "seed", y=r"$SE_{mess}$",legend=False, ax=axs[1][2],linewidth=lw)
#axs[0][0].set_yscale("log")
#axs[0][0].set_xlim([0,200])
axs[0][0].set_title(r"$T_{\rm obs} = 12$")
axs[0][0].set_ylabel(r"${\rm SE}_{\rm mess}$")
axs[0][1].set_title(r"$T_{\rm obs} = 13$")
axs[0][2].set_title(r"$T_{\rm obs} = 14$")
axs[1][0].set_title(r"$T_{\rm obs} = 15$")
axs[1][0].set_ylabel(r"${\rm SE}_{\rm mess}$")
axs[1][1].set_title(r"$T_{\rm obs} = 16$")
axs[1][2].set_title(r"$T_{\rm obs} = 17$")
plt.tight_layout()
fig.savefig(save_dir + f"Figure12.pdf")
